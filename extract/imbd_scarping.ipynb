# %%
import pandas as pd

# %% [markdown]
# <p align="center">
#   <img src="https://miro.medium.com/v2/resize:fit:1400/1*O4ey_K0ZbsESf8na7OirJg.jpeg" alt="MRI Segmentation" width="700"/>
# </p>

# %% [markdown]
# <div style="background-color:#1e1e1e; padding: 20px; border-radius: 15px; box-shadow: 0 2px 4px 0 #252526; line-height: 1.8em;">
#     <h2 style="color:#569cd6; font-size:20px; text-align: justify;">🎯 Objectives</h2>
#     <ul style="font-size:18px; font-family:Calibri, sans-serif; text-align: justify; color: #d4d4d4;">
#         <li><b style="color: #9cdcfe;">ETL Process:</b> Implement an Extract, Transform, Load (ETL) pipeline to extract movie data from the IMDB website, preprocess it, and store it in a MySQL database.</li>
#         <li><b style="color: #9cdcfe;">Data Extraction:</b> Scrape movie-related data, including titles, release years, ratings, directors, genres, and additional metadata using Python libraries such as BeautifulSoup and requests.</li>
#         <li><b style="color: #9cdcfe;">Data Preprocessing:</b> Clean and transform the extracted data by handling missing values, removing duplicates, normalizing categorical variables, and integrating the cast and crew dataset.</li>
#         <li><b style="color: #9cdcfe;">Database Integration:</b> Set up a MySQL database, create necessary tables, and load the transformed dataset using Python.</li>
#         <li><b style="color: #9cdcfe;">SQL Query Execution:</b> Execute at least three SQL queries to extract insights from the integrated dataset, such as retrieving summary statistics, filtering data, or performing joins.</li>
#         <li><b style="color: #9cdcfe;">Submission Compliance:</b> Ensure that the Jupyter Notebook file follows the required naming convention and submit it through the designated assignment portal before the deadline.</li>
#     </ul>
# </div>

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3.5rem; color: #f8f8f2; text-align: center; margin: 0; text-shadow: 4px 4px 8px rgba(0, 0, 0, 0.6); background: linear-gradient(135deg, #282a36, #44475a); padding: 30px; border-radius: 20px; border: 6px solid #ff5555; width: 95%; letter-spacing: 2px; text-transform: uppercase;">
#   🚀 <span style="color: #ffb86c;">Task 1:</span> <span style="color: #50fa7b;">Data Extracting</span> <span style="color: #8be9fd;">(Scraping)</span> 🕵️‍♂️
# </p>

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: #f5f5f5; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #1a1a1a; padding: 20px; border-radius: 20px; border: 7px solid #ff6f61; width: 95%;">
#   <span style="font-weight: bold; color: #ff6347; animation: pulse 2s infinite;"> Importing   </span>
#   <span style="font-style: italic; color: #32CD32; animation: pulse 2s infinite;"> Libraries 📚</span>
# </p>
#
# <style>
# @keyframes pulse {
#   0% {
#     transform: scale(1);
#   }
#   50% {
#     transform: scale(1.05);
#   }
#   100% {
#     transform: scale(1);
#   }
# }
# </style>

# %%
import pandas as pd 
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import re
import time
import random
from mysql import connector
from sqlalchemy import create_engine,text
from selenium.webdriver.support import expected_conditions as EC

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: #e0e0e0; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); background-color: #2c2f33; padding: 20px; border-radius: 20px; border: 7px solid #7289da; width: 95%;">
#   <span style="font-weight: bold; color: #ffcc00; animation: pulse 2s infinite;">Basic Movie Information </span>
#   <span style="font-style: italic; color: #50fa7b; animation: pulse 2s infinite;">& Additional Metadata 🎬</span>
# </p>
#
# <style>
# @keyframes pulse {
#   0% {
#     transform: scale(1);
#   }
#   50% {
#     transform: scale(1.05);
#   }
#   100% {
#     transform: scale(1);
#   }
# }
# </style>

# %%
class Extract_Data:
    def __init__(self, url):
        """Initialize the scraper with target URL and empty DataFrame"""
        self.url = url
        self.links = []  # List to store movie links
        # DataFrame structure to store all movie details
        self.df = pd.DataFrame(columns=[
            'Movie_ID', 'Rank', 'Title', 'Release Year', 'Rating',
            'Directors', 'Genres', 'Release Date', 'Country of Origin',
            'Official Sites', 'Languages', 'Locations',
            'Production Companies', 'Gross Worldwide'
        ])
        
    def Extract_Links(self):
        """Extract all movie links from the top charts page"""
        print("Starting to extract movie links...")
        
        drive = webdriver.Chrome()
        drive.get(self.url)
        
        # Scroll to the bottom of the page to load all movies
        print("Scrolling to load all movies...")
        last_height = drive.execute_script("return document.body.scrollHeight")
        while True:
            drive.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)  # Wait for content to load
            new_height = drive.execute_script("return document.body.scrollHeight")
            if last_height == new_height:
                break
            last_height = new_height
        
        # Parse the page and extract links
        soup = BeautifulSoup(drive.page_source, 'html.parser')
        movies_links = soup.find_all('a', {'href': re.compile(r'/title/tt\d+/\?ref_=chttp_t_\d+')})
        self.links = [f"https://www.imdb.com/{link.get('href')}" for link in movies_links]
        
        print(f"Successfully extracted {len(self.links)} movie links!")
        drive.quit()
        
    def Extract_Data(self):
        """Extract detailed information for each movie"""
        print("\nStarting to extract movie details...")
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36",
            "Accept-Language": "en-US,en;q=0.9"  
        }

        list_result = []
        
        # Process first 5 movies for demonstration (remove [:5] for all movies)
        for index, link in enumerate(self.links, 1):
            print(f"\nProcessing movie {index}/{len(self.links)}...")
            
            try:
                # Fetch movie page
                request = requests.get(link, headers=headers)
                soup = BeautifulSoup(request.text, 'html.parser')
                time.sleep(random.uniform(1, 3))

                
                print(f"Successfully fetched: {link}")
            except:
                print('Error connecting to server')
                continue
                
            # Extract all movie details with error handling
            try:
                title_element = soup.find('span', {'data-testid': 'hero__primary-text'})
                if title_element:
                    title_film = title_element.text
                    print(f"English Title: {title_film}")

            except AttributeError:
                title_film = None
                print("Title not found")
                
            try:
                Release_Year = soup.title.text.rsplit(maxsplit=3)[:2][1]
                print(f"Release Year: {Release_Year}")
            except AttributeError:
                Release_Year = None
                print("Release year not found")
                
            try:    
                rating = soup.find('span', class_='sc-d541859f-1 imUuxf').text
                print(f"Rating: {rating}")
            except AttributeError:
                rating = None
                print("Rating not found")
                
            try:
                Director = soup.find('a', class_='ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link').text
                print(f"Director: {Director}")
            except AttributeError:
                Director = None
                print("Director not found")
            
            try:
                Genre = [i.text for i in soup.find_all('a', class_='ipc-chip ipc-chip--on-baseAlt')]
                Genre = ','.join(Genre)
                print(f"Genres: {Genre}")
            except AttributeError:
                Genre = None
                print("Genres not found")
                
            try:
                release_date = soup.find('a', {'href': re.compile(r'/releaseinfo')}).text.strip()
                print(f"Release Date: {release_date}")
            except AttributeError:
                release_date = None
                print("Release date not found")
            
            try:
                country = soup.find('a', {'href': re.compile(r'/search/title/\?country_of_origin=')}).text
                print(f"Country: {country}")
            except AttributeError:
                country = None
                print("Country not found")
                
            try:
                official_sites = [link['href'] for link in soup.find_all('a', {'href': re.compile(r'https://')})]
                print(f"Official Sites: {len(official_sites)} found")
            except AttributeError:
                official_sites = None
                print("Official sites not found")
                
            try:
                languages = [lang.text for lang in soup.find_all('a', {'href': re.compile(r'/search/title/\?title_type=feature&primary_language=')})]
                languages = ','.join(languages)
                print(f"Languages: {languages}")
            except AttributeError:
                languages = None
                print("Languages not found")
                
            try:
                location = soup.find('a', {'href': re.compile(r'/search/title/\?locations=')}).text
                print(f"Filming Location: {location}")
            except AttributeError:
                location = None
                print("Location not found")
                
            try:
                production_companies = [prod.text for prod in soup.find_all('a', {'href': re.compile(r'/company/co')})]
                production_companies = ','.join(production_companies)
                print(f"Production Companies: {production_companies}")
            except AttributeError:
                production_companies = None
                print("Production companies not found")
                
            try:
                gross_world = soup.find(string="Gross worldwide").find_next().text.strip()
                print(f"Gross Worldwide: {gross_world}")
            except AttributeError:
                gross_world = None
                print("Gross worldwide not found")
            
            # Compile all extracted data
            dict_ = {
                'Movie_ID': re.search(r'/tt(\d+)/', link).group(1),
                'Rank': index,
                'Title': title_film,
                'Release Year': Release_Year,
                'Rating': rating,
                'Directors': Director,
                'Genres': Genre,
                'Release Date': release_date,
                'Country of Origin': country,
                'Official Sites': official_sites,
                'Languages': languages,
                'Locations': location,
                'Production Companies': production_companies,
                'Gross Worldwide': gross_world
            }
            
            list_result.append(dict_)
            print(f"Successfully processed movie {index}")
        
        # Create DataFrame with all results
        self.df = pd.DataFrame(list_result)
        print("\nAll movies processed successfully!")
        return self.df


# Main execution
if __name__ == "__main__":
    print("=====================================")
    print("       IMDb TOP MOVIES SCRAPER       ")
    print("=====================================\n")
    
    object1 = Extract_Data('https://www.imdb.com/chart/top/')
    print("\nExtracting movie links...")
    links = object1.Extract_Links()
    all_links=object1.links
    
    print("\nExtracting movie details...")
    data = object1.Extract_Data()
    
    # Save to CSV
    data.to_csv('imdb_top_moviess.csv', index=False)
    pd.DataFrame(all_links,columns=['Links']).to_csv('Links.cvs',index=False)
    print("\nResults saved to 'imdb_top_movies.csv'")
# Out:
# =====================================
#        IMDb TOP MOVIES SCRAPER
# =====================================
#
#
# Extracting movie links...
# Starting to extract movie links...
# Scrolling to load all movies...
# Successfully extracted 250 movie links!
#
# Extracting movie details...
#
# Starting to extract movie details...
#
# Processing movie 1/250...
# Successfully fetched: https://www.imdb.com//title/tt0111161/?ref_=chttp_t_1
# English Title: The Shawshank Redemption
# Release Year: (1994)
# Rating: 9.3
# Director: Frank Darabont
# Genres: Epic,Period Drama,Prison Drama,Drama
# Release Date: 1994
# Country: United States
# Official Sites: 52 found
# Languages: English
# Filming Location: Mansfield Reformatory - 100 Reformatory Road, Mansfield, Ohio, USA
# Production Companies: Castle Rock Entertainment
# Gross Worldwide: $29,332,133
# Successfully processed movie 1
#
# Processing movie 2/250...
# Successfully fetched: https://www.imdb.com//title/tt0068646/?ref_=chttp_t_2
# English Title: The Godfather
# Release Year: (1972)
# Rating: 9.2
# Director: Francis Ford Coppola
# Genres: Epic,Gangster,Tragedy,Crime,Drama
# Release Date: 1972
# Country: United States
# Official Sites: 52 found
# Languages: English,Italian,Latin
# Filming Location: Forza d'Agrò, Messina, Sicily, Italy
# Production Companies: Paramount Pictures,Albert S. Ruddy Productions,Alfran Productions
# Gross Worldwide: $250,342,198
# Successfully processed movie 2
#
# Processing movie 3/250...
# Successfully fetched: https://www.imdb.com//title/tt0468569/?ref_=chttp_t_3
# English Title: The Dark Knight
# Release Year: (2008)
# Rating: 9.0
# Director: Christopher Nolan
# Genres: Action Epic,Epic,Superhero,Tragedy,Action,Crime,Drama,Thriller
# Release Date: 2008
# Country: United States
# Official Sites: 52 found
# Languages: English,Mandarin
# Filming Location: Chicago, Illinois, USA
# Production Companies: Warner Bros.,Legendary Entertainment,Syncopy
# Gross Worldwide: $1,009,057,329
# Successfully processed movie 3
#
# Processing movie 4/250...
# Successfully fetched: https://www.imdb.com//title/tt0071562/?ref_=chttp_t_4
# English Title: The Godfather Part II
# Release Year: (1974)
# Rating: 9.0
# Director: Francis Ford Coppola
# Genres: Epic,Gangster,Tragedy,Crime,Drama
# Release Date: 1974
# Country: United States
# Official Sites: 52 found
# Languages: English,Italian,Spanish,Latin,Sicilian
# Filming Location: Kaiser Estate - 4000 W Lake Blvd, Homewood, Lake Tahoe, California, USA
# Production Companies: Paramount Pictures,The Coppola Company,American Zoetrope
# Gross Worldwide: $47,980,865
# Successfully processed movie 4
#
# Processing movie 5/250...
# Successfully fetched: https://www.imdb.com//title/tt0050083/?ref_=chttp_t_5
# English Title: 12 Angry Men
# Release Year: (1957)
# Rating: 9.0
# Director: Sidney Lumet
# Genres: Legal Drama,Psychological Drama,Crime,Drama
# Release Date: 1957
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: New York County Courthouse - 60 Centre Street, New York City, New York, USA
# Production Companies: Orion-Nova Productions
# Gross Worldwide: $2,945
# Successfully processed movie 5
#
# Processing movie 6/250...
# Successfully fetched: https://www.imdb.com//title/tt0167260/?ref_=chttp_t_6
# English Title: The Lord of the Rings: The Return of the King
# Release Year: (2003)
# Rating: 9.0
# Director: Peter Jackson
# Genres: Action Epic,Adventure Epic,Epic,Fantasy Epic,Mountain Adventure,Quest,Sword & Sorcery,Tragedy,Adventure,Drama
# Release Date: 2003
# Country: New Zealand
# Official Sites: 51 found
# Languages: English,Quenya,Old English,Sindarin
# Filming Location: Hinuera Valley, Matamata, Waikato, New Zealand
# Production Companies: New Line Cinema,WingNut Films,The Saul Zaentz Company
# Gross Worldwide: $1,138,585,992
# Successfully processed movie 6
#
# Processing movie 7/250...
# Successfully fetched: https://www.imdb.com//title/tt0108052/?ref_=chttp_t_7
# English Title: Schindler's List
# Release Year: (1993)
# Rating: 9.0
# Director: Steven Spielberg
# Genres: Docudrama,Epic,Historical Epic,Period Drama,Prison Drama,Tragedy,Biography,Drama,History
# Release Date: 1993
# Country: United States
# Official Sites: 52 found
# Languages: English,Hebrew,German,Polish,Latin
# Filming Location: Auschwitz-Birkenau Concentration Camp, Oswiecim, Malopolskie, Poland
# Production Companies: Universal Pictures,Amblin Entertainment
# Gross Worldwide: $322,161,245
# Successfully processed movie 7
#
# Processing movie 8/250...
# Successfully fetched: https://www.imdb.com//title/tt0110912/?ref_=chttp_t_8
# English Title: Pulp Fiction
# Release Year: (1994)
# Rating: 8.9
# Director: Quentin Tarantino
# Genres: Dark Comedy,Drug Crime,Gangster,Crime,Drama
# Release Date: 1994
# Country: United States
# Official Sites: 50 found
# Languages: English,Spanish,French
# Filming Location: 1435 Flower Street, Glendale, California, USA
# Production Companies: Miramax,A Band Apart,Jersey Films
# Gross Worldwide: $213,928,762
# Successfully processed movie 8
#
# Processing movie 9/250...
# Successfully fetched: https://www.imdb.com//title/tt0120737/?ref_=chttp_t_9
# English Title: The Lord of the Rings: The Fellowship of the Ring
# Release Year: (2001)
# Rating: 8.9
# Director: Peter Jackson
# Genres: Action Epic,Adventure Epic,Dark Fantasy,Epic,Fantasy Epic,Quest,Sword & Sorcery,Adventure,Drama,Fantasy
# Release Date: 2001
# Country: New Zealand
# Official Sites: 52 found
# Languages: English,Sindarin
# Filming Location: Wellington, New Zealand
# Production Companies: New Line Cinema,WingNut Films,Marzano Films
# Gross Worldwide: $888,483,037
# Successfully processed movie 9
#
# Processing movie 10/250...
# Successfully fetched: https://www.imdb.com//title/tt0060196/?ref_=chttp_t_10
# English Title: The Good, the Bad and the Ugly
# Release Year: (1966)
# Rating: 8.8
# Director: Sergio Leone
# Genres: Adventure Epic,Dark Comedy,Desert Adventure,Epic,Period Drama,Quest,Spaghetti Western,Western Epic,Adventure,Western
# Release Date: 1966
# Country: Italy
# Official Sites: 51 found
# Languages: Italian
# Filming Location: Carazo, Burgos, Castilla y León, Spain
# Production Companies: Produzioni Europee Associate (PEA),Arturo González Producciones Cinematográficas,Constantin Film
# Gross Worldwide: $25,265,416
# Successfully processed movie 10
#
# Processing movie 11/250...
# Successfully fetched: https://www.imdb.com//title/tt0109830/?ref_=chttp_t_11
# English Title: Forrest Gump
# Release Year: (1994)
# Rating: 8.8
# Director: Robert Zemeckis
# Genres: Epic,Drama,Romance
# Release Date: 1994
# Country: United States
# Official Sites: 52 found
# Languages: English
# Filming Location: Chippewa Square, Savannah, Georgia, USA
# Production Companies: Paramount Pictures,The Steve Tisch Company,Wendy Finerman Productions
# Gross Worldwide: $678,226,465
# Successfully processed movie 11
#
# Processing movie 12/250...
# Successfully fetched: https://www.imdb.com//title/tt0167261/?ref_=chttp_t_12
# English Title: The Lord of the Rings: The Two Towers
# Release Year: (2002)
# Rating: 8.8
# Director: Peter Jackson
# Genres: Action Epic,Adventure Epic,Dark Fantasy,Epic,Fantasy Epic,Quest,Sword & Sorcery,Adventure,Drama,Fantasy
# Release Date: 2002
# Country: New Zealand
# Official Sites: 51 found
# Languages: English,Sindarin,Old English
# Filming Location: Hinuera Valley, Matamata, Waikato, New Zealand
# Production Companies: New Line Cinema,WingNut Films,The Saul Zaentz Company
# Gross Worldwide: $938,532,865
# Successfully processed movie 12
#
# Processing movie 13/250...
# Successfully fetched: https://www.imdb.com//title/tt0137523/?ref_=chttp_t_13
# English Title: Fight Club
# Release Year: (1999)
# Rating: 8.8
# Director: David Fincher
# Genres: Psychological Drama,Psychological Thriller,Workplace Drama,Crime,Drama,Thriller
# Release Date: 1999
# Country: Germany
# Official Sites: 52 found
# Languages: English
# Filming Location: 240 North Neptune Avenue, Los Angeles, California, USA
# Production Companies: Fox 2000 Pictures,New Regency Productions,Linson Films
# Gross Worldwide: $101,321,009
# Successfully processed movie 13
#
# Processing movie 14/250...
# Successfully fetched: https://www.imdb.com//title/tt1375666/?ref_=chttp_t_14
# English Title: Inception
# Release Year: (2010)
# Rating: 8.8
# Director: Christopher Nolan
# Genres: Action Epic,Adventure Epic,Epic,Psychological Thriller,Sci-Fi Epic,Action,Adventure,Sci-Fi,Thriller
# Release Date: 2010
# Country: United States
# Official Sites: 50 found
# Languages: English,Japanese,French
# Filming Location: Fortress Mountain, Kananaskis Country, Alberta, Canada
# Production Companies: Warner Bros.,Legendary Entertainment,Syncopy
# Gross Worldwide: $839,381,898
# Successfully processed movie 14
#
# Processing movie 15/250...
# Successfully fetched: https://www.imdb.com//title/tt0080684/?ref_=chttp_t_15
# English Title: Star Wars: Episode V - The Empire Strikes Back
# Release Year: (1980)
# Rating: 8.7
# Director: Irvin Kershner
# Genres: Action Epic,Adventure Epic,Dark Fantasy,Dystopian Sci-Fi,Epic,Fantasy Epic,Globetrotting Adventure,Quest,Sci-Fi Epic,Space Sci-Fi
# Release Date: 1980
# Country: United States
# Official Sites: 52 found
# Languages: English
# Filming Location: Hardangerjøkulen Glacier, Finse, Norway
# Production Companies: Lucasfilm
# Gross Worldwide: $550,016,086
# Successfully processed movie 15
#
# Processing movie 16/250...
# Successfully fetched: https://www.imdb.com//title/tt0133093/?ref_=chttp_t_16
# English Title: The Matrix
# Release Year: (1999)
# Rating: 8.7
# Director: Lana Wachowski
# Genres: Action Epic,Artificial Intelligence,Cyberpunk,Dystopian Sci-Fi,Gun Fu,Martial Arts,Sci-Fi Epic,Action,Sci-Fi
# Release Date: 1999
# Country: United States
# Official Sites: 52 found
# Languages: English
# Filming Location: Nashville, Tennessee, USA
# Production Companies: Warner Bros.,Village Roadshow Pictures,Groucho Film Partnership
# Gross Worldwide: $467,841,735
# Successfully processed movie 16
#
# Processing movie 17/250...
# Successfully fetched: https://www.imdb.com//title/tt0099685/?ref_=chttp_t_17
# English Title: Goodfellas
# Release Year: (1990)
# Rating: 8.7
# Director: Martin Scorsese
# Genres: Docudrama,Gangster,True Crime,Biography,Crime,Drama
# Release Date: 1990
# Country: United States
# Official Sites: 51 found
# Languages: English,Italian,Hebrew,Yiddish
# Filming Location: The Oriental Manor, 1818 86th St, Brooklyn, New York City, New York, USA
# Production Companies: Warner Bros.
# Gross Worldwide: $47,063,985
# Successfully processed movie 17
#
# Processing movie 18/250...
# Successfully fetched: https://www.imdb.com//title/tt0816692/?ref_=chttp_t_18
# English Title: Interstellar
# Release Year: (2014)
# Rating: 8.7
# Director: Christopher Nolan
# Genres: Adventure Epic,Epic,Quest,Sci-Fi Epic,Space Sci-Fi,Time Travel,Adventure,Drama,Sci-Fi
# Release Date: 2014
# Country: United States
# Official Sites: 52 found
# Languages: English
# Filming Location: Iceland
# Production Companies: Paramount Pictures,Warner Bros.,Legendary Entertainment
# Gross Worldwide: $758,614,115
# Successfully processed movie 18
#
# Processing movie 19/250...
# Successfully fetched: https://www.imdb.com//title/tt0073486/?ref_=chttp_t_19
# English Title: One Flew Over the Cuckoo's Nest
# Release Year: (1975)
# Rating: 8.7
# Director: Milos Forman
# Genres: Medical Drama,Psychological Drama,Drama
# Release Date: 1975
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: Oregon State Mental Hospital - 2600 Center Street NE, Salem, Oregon, USA
# Production Companies: Fantasy Films,N.V. Zvaluw
# Gross Worldwide: $109,115,366
# Successfully processed movie 19
#
# Processing movie 20/250...
# Successfully fetched: https://www.imdb.com//title/tt0114369/?ref_=chttp_t_20
# English Title: Se7en
# Release Year: (1995)
# Rating: 8.6
# Director: David Fincher
# Genres: Cop Drama,Hard-boiled Detective,Legal Drama,Police Procedural,Psychological Drama,Psychological Thriller,Serial Killer,Crime,Drama,Mystery
# Release Date: 1995
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: Pacific Electric Building, Los Angeles, California, USA
# Production Companies: Arnold Kopelson Productions,Cecchi Gori Pictures,Juno Pix
# Gross Worldwide: $328,981,827
# Successfully processed movie 20
#
# Processing movie 21/250...
# Successfully fetched: https://www.imdb.com//title/tt0038650/?ref_=chttp_t_21
# English Title: It's a Wonderful Life
# Release Year: (1946)
# Rating: 8.6
# Director: Frank Capra
# Genres: Feel-Good Romance,Holiday Family,Holiday Romance,Psychological Drama,Supernatural Fantasy,Drama,Family,Fantasy,Holiday,Romance
# Release Date: 1946
# Country: United States
# Official Sites: 52 found
# Languages: English,French
# Filming Location: 4587 Viro Road, La Cañada Flintridge, California, USA
# Production Companies: Liberty Films (II)
# Gross Worldwide: $10,635,461
# Successfully processed movie 21
#
# Processing movie 22/250...
# Successfully fetched: https://www.imdb.com//title/tt0102926/?ref_=chttp_t_22
# English Title: The Silence of the Lambs
# Release Year: (1991)
# Rating: 8.6
# Director: Jonathan Demme
# Genres: Police Procedural,Psychological Drama,Psychological Horror,Psychological Thriller,Serial Killer,Slasher Horror,Crime,Drama,Horror,Thriller
# Release Date: 1991
# Country: United States
# Official Sites: 52 found
# Languages: English,Latin
# Filming Location: Bimini Airport, South Bimini Island, Bimini Islands, Bahamas
# Production Companies: Strong Heart/Demme Production,Orion Pictures
# Gross Worldwide: $272,742,922
# Successfully processed movie 22
#
# Processing movie 23/250...
# Successfully fetched: https://www.imdb.com//title/tt0047478/?ref_=chttp_t_23
# English Title: Seven Samurai
# Release Year: (1954)
# Rating: 8.6
# Director: Akira Kurosawa
# Genres: Action Epic,Epic,Period Drama,Samurai,Action,Drama
# Release Date: 1954
# Country: Japan
# Official Sites: 51 found
# Languages: Japanese
# Filming Location: Izu Peninsula, Shizuoka, Japan
# Production Companies: Toho
# Gross Worldwide: $1,082,148
# Successfully processed movie 23
#
# Processing movie 24/250...
# Successfully fetched: https://www.imdb.com//title/tt0120815/?ref_=chttp_t_24
# English Title: Saving Private Ryan
# Release Year: (1998)
# Rating: 8.6
# Director: Steven Spielberg
# Genres: Epic,Period Drama,War Epic,Drama,War
# Release Date: 1998
# Country: United States
# Official Sites: 52 found
# Languages: English,French,German,Czech
# Filming Location: Curracloe Beach, Ballinesker, County Wexford, Ireland
# Production Companies: Dreamworks Pictures,Paramount Pictures,Amblin Entertainment
# Gross Worldwide: $482,352,390
# Successfully processed movie 24
#
# Processing movie 25/250...
# Successfully fetched: https://www.imdb.com//title/tt0317248/?ref_=chttp_t_25
# English Title: City of God
# Release Year: (2002)
# Rating: 8.6
# Director: Fernando Meirelles
# Genres: Caper,Coming-of-Age,Gangster,Crime,Drama
# Release Date: 2002
# Country: Brazil
# Official Sites: 52 found
# Languages: Portuguese
# Filming Location: Rio de Janeiro, Rio de Janeiro, Brazil
# Production Companies: O2 Filmes,VideoFilmes,Globo Filmes
# Gross Worldwide: $30,681,033
# Successfully processed movie 25
#
# Processing movie 26/250...
# Successfully fetched: https://www.imdb.com//title/tt0120689/?ref_=chttp_t_26
# English Title: The Green Mile
# Release Year: (1999)
# Rating: 8.6
# Director: Frank Darabont
# Genres: Period Drama,Prison Drama,Supernatural Fantasy,Tragedy,Crime,Drama,Fantasy,Mystery
# Release Date: 1999
# Country: United States
# Official Sites: 51 found
# Languages: English,French
# Filming Location: Tennessee State Penitentiary, Nashville, Tennessee, USA
# Production Companies: Castle Rock Entertainment,Darkwoods Productions,Warner Bros.
# Gross Worldwide: $286,801,374
# Successfully processed movie 26
#
# Processing movie 27/250...
# Successfully fetched: https://www.imdb.com//title/tt0118799/?ref_=chttp_t_27
# English Title: Life Is Beautiful
# Release Year: (1997)
# Rating: 8.6
# Director: Roberto Benigni
# Genres: Period Drama,Romantic Comedy,Tragedy,Tragic Romance,Comedy,Drama,Romance,War
# Release Date: 1997
# Country: Italy
# Official Sites: 52 found
# Languages: Italian,German,English
# Filming Location: Arezzo, Tuscany, Italy
# Production Companies: Melampo Cinematografica,Cecchi Gori Group Tiger Cinematografica
# Gross Worldwide: $230,099,013
# Successfully processed movie 27
#
# Processing movie 28/250...
# Successfully fetched: https://www.imdb.com//title/tt0103064/?ref_=chttp_t_28
# English Title: Terminator 2: Judgment Day
# Release Year: (1991)
# Rating: 8.6
# Director: James Cameron
# Genres: Action Epic,Artificial Intelligence,Cyberpunk,Dystopian Sci-Fi,Sci-Fi Epic,Time Travel,Action,Adventure,Sci-Fi
# Release Date: 1991
# Country: United States
# Official Sites: 51 found
# Languages: English,Spanish
# Filming Location: Bayside Parkway & Gateway Boulevard, Fremont, California, USA
# Production Companies: Carolco Pictures,Pacific Western,Lightstorm Entertainment
# Gross Worldwide: $517,778,573
# Successfully processed movie 28
#
# Processing movie 29/250...
# Successfully fetched: https://www.imdb.com//title/tt0076759/?ref_=chttp_t_29
# English Title: Star Wars: Episode IV - A New Hope
# Release Year: (1977)
# Rating: 8.6
# Director: George Lucas
# Genres: Action Epic,Adventure Epic,Dystopian Sci-Fi,Epic,Fantasy Epic,Quest,Sci-Fi Epic,Space Sci-Fi,Sword & Sorcery,Action
# Release Date: 1977
# Country: United States
# Official Sites: 53 found
# Languages: English
# Filming Location: Tikal National Park, Guatemala
# Production Companies: Lucasfilm,Twentieth Century Fox
# Gross Worldwide: $775,398,507
# Successfully processed movie 29
#
# Processing movie 30/250...
# Successfully fetched: https://www.imdb.com//title/tt0088763/?ref_=chttp_t_30
# English Title: Back to the Future
# Release Year: (1985)
# Rating: 8.5
# Director: Robert Zemeckis
# Genres: High-Concept Comedy,Teen Adventure,Teen Comedy,Time Travel,Urban Adventure,Adventure,Comedy,Sci-Fi
# Release Date: 1985
# Country: United States
# Official Sites: 52 found
# Languages: English
# Filming Location: Whittier High School - 12417 E. Philadelphia Street, Whittier, California, USA
# Production Companies: Universal Pictures,Amblin Entertainment,U-Drive Productions
# Gross Worldwide: $385,053,307
# Successfully processed movie 30
#
# Processing movie 31/250...
# Successfully fetched: https://www.imdb.com//title/tt0245429/?ref_=chttp_t_31
# English Title: Spirited Away
# Release Year: (2001)
# Rating: 8.6
# Director: Hayao Miyazaki
# Genres: Anime,Coming-of-Age,Fairy Tale,Hand-Drawn Animation,Quest,Supernatural Fantasy,Adventure,Animation,Family,Fantasy
# Release Date: 2001
# Country: Japan
# Official Sites: 51 found
# Languages: Japanese,English
# Location not found
# Production Companies: Tokuma Shoten,Studio Ghibli,Nippon Television Network (NTV)
# Gross Worldwide: $358,877,700
# Successfully processed movie 31
#
# Processing movie 32/250...
# Successfully fetched: https://www.imdb.com//title/tt0253474/?ref_=chttp_t_32
# English Title: The Pianist
# Release Year: (2002)
# Rating: 8.5
# Director: Roman Polanski
# Genres: Docudrama,Epic,Period Drama,Tragedy,War Epic,Biography,Drama,Music,War
# Release Date: 2002
# Country: France
# Official Sites: 52 found
# Languages: English,German,Russian
# Filming Location: Instalatorów, Ochota, Warsaw, Mazowieckie, Poland
# Production Companies: R.P. Productions,Heritage Films,Studio Babelsberg
# Gross Worldwide: $120,098,945
# Successfully processed movie 32
#
# Processing movie 33/250...
# Successfully fetched: https://www.imdb.com//title/tt0172495/?ref_=chttp_t_33
# English Title: Gladiator
# Release Year: (2000)
# Rating: 8.5
# Director: Ridley Scott
# Genres: Action Epic,Adventure Epic,Epic,Period Drama,Sword & Sandal,Action,Adventure,Drama
# Release Date: 2000
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: Ouarzazate, Morocco
# Production Companies: Dreamworks Pictures,Universal Pictures,Scott Free Productions
# Gross Worldwide: $465,516,248
# Successfully processed movie 33
#
# Processing movie 34/250...
# Successfully fetched: https://www.imdb.com//title/tt6751668/?ref_=chttp_t_34
# English Title: Parasite
# Release Year: (2019)
# Rating: 8.5
# Director: Bong Joon Ho
# Genres: Dark Comedy,Korean Drama,Psychological Thriller,Tragedy,Drama,Thriller
# Release Date: 2019
# Country: South Korea
# Official Sites: 53 found
# Languages: Korean,English
# Filming Location: Jahamun-ro, Buam-dong, Jongno-gu, Seoul, South Korea
# Production Companies: CJ Entertainment,Barunson E&A
# Gross Worldwide: $262,616,458
# Successfully processed movie 34
#
# Processing movie 35/250...
# Successfully fetched: https://www.imdb.com//title/tt0054215/?ref_=chttp_t_35
# English Title: Psycho
# Release Year: (1960)
# Rating: 8.5
# Director: Alfred Hitchcock
# Genres: Dark Comedy,Psychological Horror,Psychological Thriller,Slasher Horror,Suspense Mystery,Drama,Horror,Mystery,Thriller
# Release Date: 1960
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: Psycho House and Bates Motel, Backlot Universal Studios, Universal City, California, USA
# Production Companies: Alfred J. Hitchcock Productions,Shamley Productions
# Gross Worldwide: $32,248,256
# Successfully processed movie 35
#
# Processing movie 36/250...
# Successfully fetched: https://www.imdb.com//title/tt0110357/?ref_=chttp_t_36
# English Title: The Lion King
# Release Year: (1994)
# Rating: 8.5
# Director: Roger Allers
# Genres: Animal Adventure,Coming-of-Age,Hand-Drawn Animation,Jungle Adventure,Adventure,Animation,Drama,Family,Fantasy,Musical
# Release Date: 1994
# Country: United States
# Official Sites: 51 found
# Languages: English,Swahili,Xhosa,Zulu
# Filming Location: Walt Disney Animation Studios - 2100 Riverside Drive, Burbank, California, USA
# Production Companies: Walt Disney Pictures,Walt Disney Animation Studios,Walt Disney Feature Animation
# Gross Worldwide: $979,161,373
# Successfully processed movie 36
#
# Processing movie 37/250...
# Successfully fetched: https://www.imdb.com//title/tt0095327/?ref_=chttp_t_37
# English Title: Grave of the Fireflies
# Release Year: (1988)
# Rating: 8.5
# Director: Isao Takahata
# Genres: Adult Animation,Anime,Hand-Drawn Animation,Period Drama,Tragedy,Animation,Drama,War
# Release Date: 1988
# Country: Japan
# Official Sites: 51 found
# Languages: Japanese
# Location not found
# Production Companies: Shinchosha,Studio Ghibli
# Gross Worldwide: $839,052
# Successfully processed movie 37
#
# Processing movie 38/250...
# Successfully fetched: https://www.imdb.com//title/tt0407887/?ref_=chttp_t_38
# English Title: The Departed
# Release Year: (2006)
# Rating: 8.5
# Director: Martin Scorsese
# Genres: Cop Drama,Epic,Gangster,Crime,Drama,Thriller
# Release Date: 2006
# Country: United States
# Official Sites: 50 found
# Languages: English,Cantonese
# Filming Location: SUNY Maritime College, Bronx, New York City, New York, USA
# Production Companies: Warner Bros.,Plan B Entertainment,Initial Entertainment Group (IEG)
# Gross Worldwide: $291,481,358
# Successfully processed movie 38
#
# Processing movie 39/250...
# Successfully fetched: https://www.imdb.com//title/tt2582802/?ref_=chttp_t_39
# English Title: Whiplash
# Release Year: (2014)
# Rating: 8.5
# Director: Damien Chazelle
# Genres: Psychological Drama,Drama,Music
# Release Date: 2014
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: Santa Clarita, California, USA
# Production Companies: Bold Films,Blumhouse Productions,Right of Way Films
# Gross Worldwide: $50,360,880
# Successfully processed movie 39
#
# Processing movie 40/250...
# Successfully fetched: https://www.imdb.com//title/tt0056058/?ref_=chttp_t_40
# English Title: Harakiri
# Release Year: (1962)
# Rating: 8.6
# Director: Masaki Kobayashi
# Genres: Period Drama,Drama,Mystery
# Release Date: 1962
# Country: Japan
# Official Sites: 53 found
# Languages: Japanese
# Filming Location: Kyoto, Kyoto, Japan
# Production Companies: Shochiku
# Gross Worldwide: $15,222
# Successfully processed movie 40
#
# Processing movie 41/250...
# Successfully fetched: https://www.imdb.com//title/tt0120586/?ref_=chttp_t_41
# English Title: American History X
# Release Year: (1998)
# Rating: 8.5
# Director: Tony Kaye
# Genres: Prison Drama,Tragedy,Crime,Drama
# Release Date: 1998
# Country: United States
# Official Sites: 53 found
# Languages: English
# Filming Location: Venice High School - 13000 Venice Boulevard, Venice, Los Angeles, California, USA
# Production Companies: New Line Cinema,Savoy Pictures,The Turman-Morrissey Company
# Gross Worldwide: $23,875,714
# Successfully processed movie 41
#
# Processing movie 42/250...
# Successfully fetched: https://www.imdb.com//title/tt0482571/?ref_=chttp_t_42
# English Title: The Prestige
# Release Year: (2006)
# Rating: 8.5
# Director: Christopher Nolan
# Genres: Period Drama,Steampunk,Tragedy,Drama,Mystery,Sci-Fi,Thriller
# Release Date: 2006
# Country: United Kingdom
# Official Sites: 50 found
# Languages: English
# Filming Location: Durango and Silverton Narrow Gauge Railroad, Colorado, USA
# Production Companies: Touchstone Pictures,Warner Bros.,Newmarket Films
# Gross Worldwide: $109,676,311
# Successfully processed movie 42
#
# Processing movie 43/250...
# Successfully fetched: https://www.imdb.com//title/tt0110413/?ref_=chttp_t_43
# English Title: Léon: The Professional
# Release Year: (1994)
# Rating: 8.5
# Director: Luc Besson
# Genres: Gangster,One-Person Army Action,Action,Crime,Drama,Thriller
# Release Date: 1994
# Country: France
# Official Sites: 52 found
# Languages: English,Italian,French
# Filming Location: Paris, France
# Production Companies: Columbia Pictures,Gaumont,Les Films du Dauphin
# Gross Worldwide: $20,278,989
# Successfully processed movie 43
#
# Processing movie 44/250...
# Successfully fetched: https://www.imdb.com//title/tt9362722/?ref_=chttp_t_44
# English Title: Spider-Man: Across the Spider-Verse
# Release Year: (2023)
# Rating: 8.5
# Director: Joaquim Dos Santos
# Genres: Computer Animation,Superhero,Supernatural Fantasy,Teen Adventure,Urban Adventure,Action,Adventure,Animation,Family,Fantasy
# Release Date: 2023
# Country: United States
# Official Sites: 51 found
# Languages: English
# Location not found
# Production Companies: Columbia Pictures,Marvel Entertainment,Avi Arad Productions
# Gross Worldwide: $690,824,738
# Successfully processed movie 44
#
# Processing movie 45/250...
# Successfully fetched: https://www.imdb.com//title/tt0034583/?ref_=chttp_t_45
# English Title: Casablanca
# Release Year: (1942)
# Rating: 8.5
# Director: Michael Curtiz
# Genres: Period Drama,Psychological Drama,Drama,Romance,War
# Release Date: 1942
# Country: United States
# Official Sites: 52 found
# Languages: English,French,German,Italian,Russian
# Filming Location: Waterman Drive, Van Nuys, Los Angeles, California, USA
# Production Companies: Warner Bros.
# Gross Worldwide: $4,727,083
# Successfully processed movie 45
#
# Processing movie 46/250...
# Successfully fetched: https://www.imdb.com//title/tt0114814/?ref_=chttp_t_46
# English Title: The Usual Suspects
# Release Year: (1995)
# Rating: 8.5
# Director: Bryan Singer
# Genres: Caper,Gangster,Heist,Psychological Drama,Psychological Thriller,Suspense Mystery,Whodunnit,Crime,Drama,Mystery
# Release Date: 1995
# Country: United States
# Official Sites: 52 found
# Languages: English,Hungarian,Spanish,French
# Filming Location: Korean Friendship Bell, Angel's Gate Park - 3601 Gaffey Street, San Pedro, Los Angeles, California, USA
# Production Companies: Polygram Filmed Entertainment,Spelling Films International,Blue Parrot
# Gross Worldwide: $23,341,568
# Successfully processed movie 46
#
# Processing movie 47/250...
# Successfully fetched: https://www.imdb.com//title/tt1675434/?ref_=chttp_t_47
# English Title: The Intouchables
# Release Year: (2011)
# Rating: 8.5
# Director: Olivier Nakache
# Genres: Docudrama,Comedy,Drama
# Release Date: 2011
# Country: France
# Official Sites: 53 found
# Languages: French,English
# Filming Location: Cabourg, Calvados, France
# Production Companies: Quad,Ten Films,Canal+
# Gross Worldwide: $426,590,315
# Successfully processed movie 47
#
# Processing movie 48/250...
# Successfully fetched: https://www.imdb.com//title/tt0095765/?ref_=chttp_t_48
# English Title: Cinema Paradiso
# Release Year: (1988)
# Rating: 8.5
# Director: Giuseppe Tornatore
# Genres: Coming-of-Age,Drama,Romance
# Release Date: 1988
# Country: Italy
# Official Sites: 52 found
# Languages: Italian
# Filming Location: Cefalù, Palermo, Sicily, Italy
# Production Companies: Cristaldifilm,Les Films Ariane,Rai 3
# Gross Worldwide: $13,027,373
# Successfully processed movie 48
#
# Processing movie 49/250...
# Successfully fetched: https://www.imdb.com//title/tt0027977/?ref_=chttp_t_49
# English Title: Modern Times
# Release Year: (1936)
# Rating: 8.5
# Director: Charles Chaplin
# Genres: Romantic Comedy,Satire,Slapstick,Comedy,Drama,Romance
# Release Date: 1936
# Country: United States
# Official Sites: 53 found
# Languages: English
# Filming Location: Sierra Hwy. & Penman Rd., Santa Clarita, California, USA
# Production Companies: Charles Chaplin Productions
# Gross Worldwide: $463,618
# Successfully processed movie 49
#
# Processing movie 50/250...
# Successfully fetched: https://www.imdb.com//title/tt0078748/?ref_=chttp_t_50
# English Title: Alien
# Release Year: (1979)
# Rating: 8.5
# Director: Ridley Scott
# Genres: Alien Invasion,Cyberpunk,Monster Horror,Space Sci-Fi,Tragedy,Horror,Sci-Fi
# Release Date: 1979
# Country: United Kingdom
# Official Sites: 51 found
# Languages: English
# Filming Location: Shepperton Studios, Shepperton, Surrey, England, UK
# Production Companies: Twentieth Century Fox,Brandywine Productions,Scott Free Productions
# Gross Worldwide: $108,610,231
# Successfully processed movie 50
#
# Processing movie 51/250...
# Successfully fetched: https://www.imdb.com//title/tt0047396/?ref_=chttp_t_51
# English Title: Rear Window
# Release Year: (1954)
# Rating: 8.5
# Director: Alfred Hitchcock
# Genres: Psychological Thriller,Suspense Mystery,Drama,Mystery,Thriller
# Release Date: 1954
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: Stage 18, Paramount Studios - 5555 Melrose Avenue, Hollywood, Los Angeles, California, USA
# Production Companies: Alfred J. Hitchcock Productions
# Gross Worldwide: $37,905,475
# Successfully processed movie 51
#
# Processing movie 52/250...
# Successfully fetched: https://www.imdb.com//title/tt0064116/?ref_=chttp_t_52
# English Title: Once Upon a Time in the West
# Release Year: (1968)
# Rating: 8.5
# Director: Sergio Leone
# Genres: Desert Adventure,Epic,Spaghetti Western,Western Epic,Drama,Western
# Release Date: 1968
# Country: Italy
# Official Sites: 51 found
# Languages: Italian,English,Spanish
# Filming Location: Monument Valley, Arizona, USA
# Production Companies: Rafran Cinematografica,San Marco,Paramount Pictures
# Gross Worldwide: $5,435,312
# Successfully processed movie 52
#
# Processing movie 53/250...
# Successfully fetched: https://www.imdb.com//title/tt1853728/?ref_=chttp_t_53
# English Title: Django Unchained
# Release Year: (2012)
# Rating: 8.5
# Director: Quentin Tarantino
# Genres: Dark Comedy,Epic,One-Person Army Action,Period Drama,Western Epic,Western
# Release Date: 2012
# Country: United States
# Official Sites: 51 found
# Languages: English,German,French,Italian
# Filming Location: Evergreen Plantation - 4677 Highway 18, Edgard, Louisiana, USA
# Production Companies: The Weinstein Company,Columbia Pictures
# Gross Worldwide: $426,076,293
# Successfully processed movie 53
#
# Processing movie 54/250...
# Successfully fetched: https://www.imdb.com//title/tt0021749/?ref_=chttp_t_54
# English Title: City Lights
# Release Year: (1931)
# Rating: 8.5
# Director: Charles Chaplin
# Genres: Feel-Good Romance,Romantic Comedy,Satire,Slapstick,Comedy,Drama,Romance
# Release Date: 1931
# Country: United States
# Official Sites: 54 found
# Languages: None,English
# Filming Location: Chaplin Studios - 1416 N. La Brea Avenue, Hollywood, Los Angeles, California, USA
# Production Companies: Charles Chaplin Productions
# Gross Worldwide: $55,154
# Successfully processed movie 54
#
# Processing movie 55/250...
# Successfully fetched: https://www.imdb.com//title/tt0078788/?ref_=chttp_t_55
# English Title: Apocalypse Now
# Release Year: (1979)
# Rating: 8.4
# Director: Francis Ford Coppola
# Genres: Adventure Epic,Epic,Hard-boiled Detective,Psychological Drama,Quest,Suspense Mystery,War Epic,Drama,Mystery,War
# Release Date: 1979
# Country: United States
# Official Sites: 53 found
# Languages: English,French,Vietnamese
# Filming Location: Baler Bay, Baler, Aurora, Philippines
# Production Companies: American Zoetrope,Zoetrope Studios
# Gross Worldwide: $105,086,099
# Successfully processed movie 55
#
# Processing movie 56/250...
# Successfully fetched: https://www.imdb.com//title/tt15239678/?ref_=chttp_t_56
# English Title: Dune: Part Two
# Release Year: (2024)
# Rating: 8.5
# Director: Denis Villeneuve
# Genres: Action Epic,Desert Adventure,Epic,Sci-Fi Epic,Space Sci-Fi,Action,Adventure,Drama,Sci-Fi
# Release Date: 2024
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: Wadi Rum, Jordan
# Production Companies: Warner Bros.,Legendary Entertainment,Villeneuve Films
# Gross Worldwide: $714,644,358
# Successfully processed movie 56
#
# Processing movie 57/250...
# Successfully fetched: https://www.imdb.com//title/tt0209144/?ref_=chttp_t_57
# English Title: Memento
# Release Year: (2000)
# Rating: 8.4
# Director: Christopher Nolan
# Genres: Psychological Thriller,Suspense Mystery,Mystery,Thriller
# Release Date: 2000
# Country: United States
# Official Sites: 52 found
# Languages: English
# Filming Location: Travel Inn - 7254 Foothill Blvd., Tujunga, Los Angeles, California, USA
# Production Companies: Newmarket Capital Group,Team Todd,I Remember Productions
# Gross Worldwide: $40,047,236
# Successfully processed movie 57
#
# Processing movie 58/250...
# Successfully fetched: https://www.imdb.com//title/tt0910970/?ref_=chttp_t_58
# English Title: WALL·E
# Release Year: (2008)
# Rating: 8.4
# Director: Andrew Stanton
# Genres: Adventure Epic,Artificial Intelligence,Computer Animation,Dystopian Sci-Fi,Psychological Drama,Space Sci-Fi,Adventure,Animation,Family,Sci-Fi
# Release Date: 2008
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: Walt Disney Animation Studios - 2100 Riverside Drive, Burbank, California, USA
# Production Companies: Walt Disney Pictures,Pixar Animation Studios,FortyFour Studios
# Gross Worldwide: $527,403,656
# Successfully processed movie 58
#
# Processing movie 59/250...
# Successfully fetched: https://www.imdb.com//title/tt0082971/?ref_=chttp_t_59
# English Title: Raiders of the Lost Ark
# Release Year: (1981)
# Rating: 8.4
# Director: Steven Spielberg
# Genres: Adventure Epic,Desert Adventure,Globetrotting Adventure,Quest,Action,Adventure
# Release Date: 1981
# Country: United States
# Official Sites: 51 found
# Languages: English,German,Spanish,Nepali,Hebrew,Arabic
# Filming Location: Sidi Bouhlel, Tozeur, Tunisia
# Production Companies: Paramount Pictures,Lucasfilm
# Gross Worldwide: $389,925,971
# Successfully processed movie 59
#
# Processing movie 60/250...
# Successfully fetched: https://www.imdb.com//title/tt0405094/?ref_=chttp_t_60
# English Title: The Lives of Others
# Release Year: (2006)
# Rating: 8.4
# Director: Florian Henckel von Donnersmarck
# Genres: Political Thriller,Psychological Drama,Spy,Drama,Mystery,Thriller
# Release Date: 2006
# Country: Germany
# Official Sites: 53 found
# Languages: German
# Filming Location: Gedenkstätte Hohenschönhausen, Hohenschönhausen, Berlin, Germany
# Production Companies: Wiedemann & Berg Filmproduktion,Bayerischer Rundfunk (BR),ARTE
# Gross Worldwide: $77,672,685
# Successfully processed movie 60
#
# Processing movie 61/250...
# Successfully fetched: https://www.imdb.com//title/tt4154756/?ref_=chttp_t_61
# English Title: Avengers: Infinity War
# Release Year: (2018)
# Rating: 8.4
# Director: Anthony Russo
# Genres: Space Sci-Fi,Superhero,Action,Adventure,Sci-Fi
# Release Date: 2018
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: Cockburn Street, Edinburgh, City of Edinburgh, Scotland, UK
# Production Companies: Marvel Studios,Jason Roberts Productions,South Pictures
# Gross Worldwide: $2,052,415,039
# Successfully processed movie 61
#
# Processing movie 62/250...
# Successfully fetched: https://www.imdb.com//title/tt0043014/?ref_=chttp_t_62
# English Title: Sunset Boulevard
# Release Year: (1950)
# Rating: 8.4
# Director: Billy Wilder
# Genres: Dark Comedy,Film Noir,Psychological Drama,Showbiz Drama,Tragedy,Drama
# Release Date: 1950
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: 10060 Sunset Blvd, Los Angeles, California, USA
# Production Companies: Paramount Pictures
# Gross Worldwide: $309,467
# Successfully processed movie 62
#
# Processing movie 63/250...
# Successfully fetched: https://www.imdb.com//title/tt4633694/?ref_=chttp_t_63
# English Title: Spider-Man: Into the Spider-Verse
# Release Year: (2018)
# Rating: 8.4
# Director: Bob Persichetti
# Genres: Computer Animation,Superhero,Supernatural Fantasy,Teen Adventure,Teen Comedy,Urban Adventure,Action,Adventure,Animation,Comedy
# Release Date: 2018
# Country: Canada
# Official Sites: 50 found
# Languages: English,Spanish
# Location not found
# Production Companies: Columbia Pictures,Marvel Entertainment,Avi Arad Productions
# Gross Worldwide: $393,602,435
# Successfully processed movie 63
#
# Processing movie 64/250...
# Successfully fetched: https://www.imdb.com//title/tt0050825/?ref_=chttp_t_64
# English Title: Paths of Glory
# Release Year: (1957)
# Rating: 8.4
# Director: Stanley Kubrick
# Genres: Epic,Psychological Drama,War Epic,Drama,War
# Release Date: 1957
# Country: United States
# Official Sites: 51 found
# Languages: English,German,Latin
# Filming Location: Schloß Schleißheim, Oberschleißheim, Bavaria, Germany
# Production Companies: Bryna Productions
# Gross Worldwide: $8,290
# Successfully processed movie 64
#
# Processing movie 65/250...
# Successfully fetched: https://www.imdb.com//title/tt0051201/?ref_=chttp_t_65
# English Title: Witness for the Prosecution
# Release Year: (1957)
# Rating: 8.4
# Director: Billy Wilder
# Genres: Legal Drama,Legal Thriller,Whodunnit,Crime,Drama,Mystery,Thriller
# Release Date: 1957
# Country: United States
# Official Sites: 51 found
# Languages: English,German
# Filming Location: Metro-Goldwyn-Mayer Studios - 10202 W. Washington Blvd., Culver City, California, USA
# Production Companies: Edward Small Productions
# Gross Worldwide: $7,903
# Successfully processed movie 65
#
# Processing movie 66/250...
# Successfully fetched: https://www.imdb.com//title/tt0081505/?ref_=chttp_t_66
# English Title: The Shining
# Release Year: (1980)
# Rating: 8.4
# Director: Stanley Kubrick
# Genres: Dark Comedy,Psychological Drama,Psychological Horror,Supernatural Horror,Drama,Horror
# Release Date: 1980
# Country: United Kingdom
# Official Sites: 51 found
# Languages: English
# Filming Location: Timberline Lodge, 27500 E Timberline Road, Government Camp, Mount Hood, Oregon, USA
# Production Companies: Warner Bros.,Hawk Films,Peregrine
# Gross Worldwide: $47,964,195
# Successfully processed movie 66
#
# Processing movie 67/250...
# Successfully fetched: https://www.imdb.com//title/tt0032553/?ref_=chttp_t_67
# English Title: The Great Dictator
# Release Year: (1940)
# Rating: 8.4
# Director: Charles Chaplin
# Genres: Parody,Satire,Slapstick,Comedy,Drama,War
# Release Date: 1940
# Country: United States
# Official Sites: 53 found
# Languages: English,Esperanto,Latin
# Filming Location: Santa Monica Mountains, Los Angeles, California, USA
# Production Companies: Charles Chaplin Productions
# Gross Worldwide: $972,212
# Successfully processed movie 67
#
# Processing movie 68/250...
# Successfully fetched: https://www.imdb.com//title/tt23849204/?ref_=chttp_t_68
# English Title: 12th Fail
# Release Year: (2023)
# Rating: 8.8
# Director: Vidhu Vinod Chopra
# Genres: Docudrama,Biography,Drama
# Release Date: 2023
# Country: India
# Official Sites: 53 found
# Languages: Hindi
# Filming Location: Chambal Valley, Madhya Pradesh, India
# Production Companies: Vinod Chopra Films,Zee Studios
# Gross Worldwide: $138,288
# Successfully processed movie 68
#
# Processing movie 69/250...
# Successfully fetched: https://www.imdb.com//title/tt0090605/?ref_=chttp_t_69
# English Title: Aliens
# Release Year: (1986)
# Rating: 8.4
# Director: James Cameron
# Genres: Alien Invasion,Cyberpunk,Monster Horror,Space Sci-Fi,Survival,Tragedy,Action,Adventure,Horror,Sci-Fi
# Release Date: 1986
# Country: United Kingdom
# Official Sites: 52 found
# Languages: English,Spanish
# Filming Location: Acton Lane Power Station, Acton Lane, Acton, London, England, UK
# Production Companies: Twentieth Century Fox,Brandywine Productions,Pinewood Studios
# Gross Worldwide: $131,060,248
# Successfully processed movie 69
#
# Processing movie 70/250...
# Successfully fetched: https://www.imdb.com//title/tt0361748/?ref_=chttp_t_70
# English Title: Inglourious Basterds
# Release Year: (2009)
# Rating: 8.4
# Director: Quentin Tarantino
# Genres: Dark Comedy,Period Drama,Adventure,Drama,War
# Release Date: 2009
# Country: United States
# Official Sites: 51 found
# Languages: English,German,French,Italian
# Filming Location: Brasserie La Renaissance, 112 rue Championnet, Paris 18, Paris, France
# Production Companies: Universal Pictures,The Weinstein Company,A Band Apart
# Gross Worldwide: $321,460,744
# Successfully processed movie 70
#
# Processing movie 71/250...
# Successfully fetched: https://www.imdb.com//title/tt1345836/?ref_=chttp_t_71
# English Title: The Dark Knight Rises
# Release Year: (2012)
# Rating: 8.4
# Director: Christopher Nolan
# Genres: Action Epic,Epic,Superhero,Action,Crime,Drama,Thriller
# Release Date: 2012
# Country: United States
# Official Sites: 53 found
# Languages: English,Arabic
# Filming Location: Mehrangarh Fort, Jodhpur, Rajasthan, India
# Production Companies: Warner Bros.,Legendary Entertainment,DC Entertainment
# Gross Worldwide: $1,114,976,407
# Successfully processed movie 71
#
# Processing movie 72/250...
# Successfully fetched: https://www.imdb.com//title/tt2380307/?ref_=chttp_t_72
# English Title: Coco
# Release Year: (2017)
# Rating: 8.4
# Director: Lee Unkrich
# Genres: Computer Animation,Supernatural Fantasy,Adventure,Animation,Drama,Family,Fantasy,Music,Mystery
# Release Date: 2017
# Country: United States
# Official Sites: 52 found
# Languages: English,Spanish
# Filming Location: Pixar Animation Studios - 1200 Park Avenue, Emeryville, California, USA
# Production Companies: Walt Disney Pictures,Pixar Animation Studios,Día de Muertos
# Gross Worldwide: $814,641,172
# Successfully processed movie 72
#
# Processing movie 73/250...
# Successfully fetched: https://www.imdb.com//title/tt0086879/?ref_=chttp_t_73
# English Title: Amadeus
# Release Year: (1984)
# Rating: 8.4
# Director: Milos Forman
# Genres: Costume Drama,Epic,Period Drama,Tragedy,Biography,Drama,Music
# Release Date: 1984
# Country: United States
# Official Sites: 52 found
# Languages: English,Italian,Latin,German,French
# Filming Location: Barrandov Studios, Prague, Czech Republic
# Production Companies: The Saul Zaentz Company,AMLF
# Gross Worldwide: $52,113,524
# Successfully processed movie 73
#
# Processing movie 74/250...
# Successfully fetched: https://www.imdb.com//title/tt0114709/?ref_=chttp_t_74
# English Title: Toy Story
# Release Year: (1995)
# Rating: 8.3
# Director: John Lasseter
# Genres: Buddy Comedy,Computer Animation,Supernatural Fantasy,Urban Adventure,Adventure,Animation,Comedy,Family,Fantasy
# Release Date: 1995
# Country: United States
# Official Sites: 52 found
# Languages: English
# Filming Location: Pixar Animation Studios - 1200 Park Avenue, Emeryville, California, USA
# Production Companies: Pixar Animation Studios,Walt Disney Pictures,Pixar Animation Studios
# Gross Worldwide: $394,436,586
# Successfully processed movie 74
#
# Processing movie 75/250...
# Successfully fetched: https://www.imdb.com//title/tt4154796/?ref_=chttp_t_75
# English Title: Avengers: Endgame
# Release Year: (2019)
# Rating: 8.4
# Director: Anthony Russo
# Genres: Space Sci-Fi,Superhero,Time Travel,Tragedy,Action,Adventure,Sci-Fi
# Release Date: 2019
# Country: United States
# Official Sites: 52 found
# Languages: English,Japanese,Xhosa,German
# Filming Location: Durham Cathedral, The College, Durham, County Durham, England, UK
# Production Companies: Marvel Studios
# Gross Worldwide: $2,799,439,100
# Successfully processed movie 75
#
# Processing movie 76/250...
# Successfully fetched: https://www.imdb.com//title/tt0119217/?ref_=chttp_t_76
# English Title: Good Will Hunting
# Release Year: (1997)
# Rating: 8.3
# Director: Gus Van Sant
# Genres: Coming-of-Age,Psychological Drama,Drama,Romance
# Release Date: 1997
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: Massachusetts Turnpike, Massachusetts, USA
# Production Companies: Miramax,Lawrence Bender Productions,Be Gentlemen Limited Partnership
# Gross Worldwide: $225,933,435
# Successfully processed movie 76
#
# Processing movie 77/250...
# Successfully fetched: https://www.imdb.com//title/tt0364569/?ref_=chttp_t_77
# English Title: Oldboy
# Release Year: (2003)
# Rating: 8.3
# Director: Park Chan-wook
# Genres: Dark Comedy,One-Person Army Action,Psychological Drama,Psychological Thriller,Action,Drama,Mystery,Thriller
# Release Date: 2003
# Country: South Korea
# Official Sites: 52 found
# Languages: Korean
# Filming Location: Busan, South Korea
# Production Companies: Show East,Egg Films
# Gross Worldwide: $17,617,021
# Successfully processed movie 77
#
# Processing movie 78/250...
# Successfully fetched: https://www.imdb.com//title/tt0057012/?ref_=chttp_t_78
# English Title: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# Release Year: (1964)
# Rating: 8.3
# Director: Stanley Kubrick
# Genres: Dark Comedy,Farce,Political Drama,Satire,Tragedy,Comedy,War
# Release Date: 1964
# Country: United Kingdom
# Official Sites: 52 found
# Languages: English,Russian
# Filming Location: Banff National Park, Alberta, Canada
# Production Companies: Stanley Kubrick Productions
# Gross Worldwide: $9,631,984
# Successfully processed movie 78
#
# Processing movie 79/250...
# Successfully fetched: https://www.imdb.com//title/tt0082096/?ref_=chttp_t_79
# English Title: Das Boot
# Release Year: (1981)
# Rating: 8.4
# Director: Wolfgang Petersen
# Genres: Epic,War Epic,Drama,War
# Release Date: 1981
# Country: West Germany
# Official Sites: 52 found
# Languages: German,English,French
# Filming Location: North Sea near Heligoland
# Production Companies: Bavaria Film,Twin Bros. Productions,Radiant Film GmbH
# Gross Worldwide: $11,488,778
# Successfully processed movie 79
#
# Processing movie 80/250...
# Successfully fetched: https://www.imdb.com//title/tt0169547/?ref_=chttp_t_80
# English Title: American Beauty
# Release Year: (1999)
# Rating: 8.3
# Director: Sam Mendes
# Genres: Psychological Drama,Tragedy,Drama
# Release Date: 1999
# Country: United States
# Official Sites: 52 found
# Languages: English
# Filming Location: Sacramento, California, USA
# Production Companies: Dreamworks Pictures,Jinks/Cohen Company
# Gross Worldwide: $356,296,601
# Successfully processed movie 80
#
# Processing movie 81/250...
# Successfully fetched: https://www.imdb.com//title/tt0112573/?ref_=chttp_t_81
# English Title: Braveheart
# Release Year: (1995)
# Rating: 8.3
# Director: Mel Gibson
# Genres: Action Epic,Costume Drama,Epic,Period Drama,War Epic,Biography,Drama,War
# Release Date: 1995
# Country: United States
# Official Sites: 53 found
# Languages: English,French,Latin,Gaelic,Italian
# Filming Location: Fort William, Glen Coe, Highland, Scotland, UK
# Production Companies: Icon Entertainment International,The Ladd Company,B.H. Finance C.V.
# Gross Worldwide: $213,216,216
# Successfully processed movie 81
#
# Processing movie 82/250...
# Successfully fetched: https://www.imdb.com//title/tt0119698/?ref_=chttp_t_82
# English Title: Princess Mononoke
# Release Year: (1997)
# Rating: 8.3
# Director: Hayao Miyazaki
# Genres: Action Epic,Adult Animation,Adventure Epic,Anime,Dark Fantasy,Fantasy Epic,Hand-Drawn Animation,Quest,Adventure,Animation
# Release Date: 1997
# Country: Japan
# Official Sites: 51 found
# Languages: Japanese
# Location not found
# Production Companies: DENTSU Music And Entertainment,Nibariki,Nippon Television Network (NTV)
# Gross Worldwide: $177,220,918
# Successfully processed movie 82
#
# Processing movie 83/250...
# Successfully fetched: https://www.imdb.com//title/tt5311514/?ref_=chttp_t_83
# English Title: Your Name.
# Release Year: (2016)
# Rating: 8.4
# Director: Makoto Shinkai
# Genres: Anime,Shōjo,Animation,Drama,Fantasy,Romance
# Release Date: 2016
# Country: Japan
# Official Sites: 52 found
# Languages: Japanese
# Location not found
# Production Companies: Amuse,CoMix Wave Films,East Japan Marketing & Communications Inc.
# Gross Worldwide: $405,340,703
# Successfully processed movie 83
#
# Processing movie 84/250...
# Successfully fetched: https://www.imdb.com//title/tt0057565/?ref_=chttp_t_84
# English Title: High and Low
# Release Year: (1963)
# Rating: 8.4
# Director: Akira Kurosawa
# Genres: Police Procedural,Crime,Drama,Mystery,Thriller
# Release Date: 1963
# Country: Japan
# Official Sites: 51 found
# Languages: Japanese
# Filming Location: Toho Studios, Tokyo, Japan
# Production Companies: Toho,Kurosawa Production Co.
# Gross Worldwide: $64,503
# Successfully processed movie 84
#
# Processing movie 85/250...
# Successfully fetched: https://www.imdb.com//title/tt0252488/?ref_=chttp_t_85
# English Title: The Chaos Class Failed the Class
# Release Year: (1975)
# Rating: 8.8
# ...
#
# Processing movie 221/250...
# Successfully fetched: https://www.imdb.com//title/tt3170832/?ref_=chttp_t_221
# English Title: Room
# Release Year: (2015)
# Rating: 8.1
# Director: Lenny Abrahamson
# Genres: Psychological Drama,Drama,Thriller
# Release Date: 2015
# Country: Ireland
# Official Sites: 51 found
# Languages: English
# Filming Location: Apache Burgers, 5236 Dundas St. W., Etobicoke, Ontario, Canada
# Production Companies: Element Pictures,Bord Scannán na hÉireann / The Irish Film Board,Film4
# Gross Worldwide: $35,402,766
# Successfully processed movie 221
#
# Processing movie 222/250...
# Successfully fetched: https://www.imdb.com//title/tt0325980/?ref_=chttp_t_222
# English Title: Pirates of the Caribbean: The Curse of the Black Pearl
# Release Year: (2003)
# Rating: 8.1
# Director: Gore Verbinski
# Genres: Sea Adventure,Supernatural Fantasy,Swashbuckler,Sword & Sandal,Action,Adventure,Fantasy
# Release Date: 2003
# Country: United States
# Official Sites: 52 found
# Languages: English
# Filming Location: Samana, Dominican Republic
# Production Companies: Walt Disney Pictures,Jerry Bruckheimer Films
# Gross Worldwide: $654,264,546
# Successfully processed movie 222
#
# Processing movie 223/250...
# Successfully fetched: https://www.imdb.com//title/tt0113247/?ref_=chttp_t_223
# English Title: La haine
# Release Year: (1995)
# Rating: 8.1
# Director: Mathieu Kassovitz
# Genres: Gangster,Psychological Drama,Crime,Drama
# Release Date: 1995
# Country: France
# Official Sites: 51 found
# Languages: French,Yiddish
# Filming Location: Chanteloup-les-Vignes, Yvelines, France
# Production Companies: Les Productions Lazennec,Le Studio Canal+,La Sept Cinéma
# Gross Worldwide: $760,085
# Successfully processed movie 223
#
# Processing movie 224/250...
# Successfully fetched: https://www.imdb.com//title/tt15097216/?ref_=chttp_t_224
# English Title: Jai Bhim
# Release Year: (2021)
# Rating: 8.7
# Director: T.J. Gnanavel
# Genres: Legal Drama,Crime,Drama
# Release Date: 2021
# Country: India
# Official Sites: 48 found
# Languages: Tamil
# Location not found
# Production Companies: 2D Entertainment
# Gross worldwide not found
# Successfully processed movie 224
#
# Processing movie 225/250...
# Successfully fetched: https://www.imdb.com//title/tt0395169/?ref_=chttp_t_225
# English Title: Hotel Rwanda
# Release Year: (2004)
# Rating: 8.1
# Director: Terry George
# Genres: Docudrama,Epic,Biography,Drama,History,War
# Release Date: 2004
# Country: United States
# Official Sites: 51 found
# Languages: English,French,Kinyarwanda
# Filming Location: Kigali, Rwanda
# Production Companies: United Artists,Lionsgate,Industrial Development Corporation of South Africa
# Gross Worldwide: $33,882,243
# Successfully processed movie 225
#
# Processing movie 226/250...
# Successfully fetched: https://www.imdb.com//title/tt0091763/?ref_=chttp_t_226
# English Title: Platoon
# Release Year: (1986)
# Rating: 8.1
# Director: Oliver Stone
# Genres: Drama,War
# Release Date: 1986
# Country: United States
# Official Sites: 52 found
# Languages: English,Vietnamese
# Filming Location: Philippines
# Production Companies: Hemdale,Cinema '84,Cinema 86
# Gross Worldwide: $138,546,255
# Successfully processed movie 226
#
# Processing movie 227/250...
# Successfully fetched: https://www.imdb.com//title/tt0036868/?ref_=chttp_t_227
# English Title: The Best Years of Our Lives
# Release Year: (1946)
# Rating: 8.1
# Director: William Wyler
# Genres: Epic,Feel-Good Romance,Drama,Romance,War
# Release Date: 1946
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: Ontario International Airport - 2900 E. Airport Drive, Ontario, California, USA
# Production Companies: Samuel Goldwyn Productions
# Gross Worldwide: $23,667,133
# Successfully processed movie 227
#
# Processing movie 228/250...
# Successfully fetched: https://www.imdb.com//title/tt0381681/?ref_=chttp_t_228
# English Title: Before Sunset
# Release Year: (2004)
# Rating: 8.1
# Director: Richard Linklater
# Genres: Feel-Good Romance,Drama,Romance
# Release Date: 2004
# Country: France
# Official Sites: 51 found
# Languages: English,French
# Filming Location: Seine River, Paris, France
# Production Companies: Warner Independent Pictures (WIP),Castle Rock Entertainment,Detour Filmproduction
# Gross Worldwide: $16,506,532
# Successfully processed movie 228
#
# Processing movie 229/250...
# Successfully fetched: https://www.imdb.com//title/tt0070047/?ref_=chttp_t_229
# English Title: The Exorcist
# Release Year: (1973)
# Rating: 8.1
# Director: William Friedkin
# Genres: Body Horror,Psychological Drama,Psychological Horror,Supernatural Horror,Tragedy,Horror
# Release Date: 1973
# Country: United States
# Official Sites: 51 found
# Languages: English,Latin,Greek,French,German,Arabic,Kurdish
# Filming Location: Mosul, Iraq
# Production Companies: Warner Bros.,Hoya Productions
# Gross Worldwide: $430,872,776
# Successfully processed movie 229
#
# Processing movie 230/250...
# Successfully fetched: https://www.imdb.com//title/tt0019254/?ref_=chttp_t_230
# English Title: The Passion of Joan of Arc
# Release Year: (1928)
# Rating: 8.1
# Director: Carl Theodor Dreyer
# Genres: Legal Drama,Period Drama,Psychological Drama,Tragedy,Biography,Drama,History
# Release Date: 1928
# Country: France
# Official Sites: 51 found
# Languages: None,French,Latin
# Filming Location: Boulogne-Billancourt, Hauts-de-Seine, France
# Production Companies: Société générale des films
# Gross Worldwide: $22,731
# Successfully processed movie 230
#
# Processing movie 231/250...
# Successfully fetched: https://www.imdb.com//title/tt0032138/?ref_=chttp_t_231
# English Title: The Wizard of Oz
# Release Year: (1939)
# Rating: 8.1
# Director: Victor Fleming
# Genres: Adventure Epic,Classic Musical,Fairy Tale,Fantasy Epic,Quest,Adventure,Family,Fantasy,Musical
# Release Date: 1939
# Country: United States
# Official Sites: 52 found
# Languages: English
# Filming Location: Stage 28, Sony Pictures Studios - 10202 W. Washington Blvd., Culver City, California, USA
# Production Companies: Metro-Goldwyn-Mayer (MGM)
# Gross Worldwide: $25,637,669
# Successfully processed movie 231
#
# Processing movie 232/250...
# Successfully fetched: https://www.imdb.com//title/tt0059742/?ref_=chttp_t_232
# English Title: The Sound of Music
# Release Year: (1965)
# Rating: 8.1
# Director: Robert Wise
# Genres: Classic Musical,Epic,Period Drama,Biography,Drama,Family,Musical,Romance
# Release Date: 1965
# Country: United States
# Official Sites: 53 found
# Languages: English,German
# Filming Location: Felsenreitschule, Salzburg, Austria
# Production Companies: Robert Wise Productions,Argyle Enterprises
# Gross Worldwide: $159,485,474
# Successfully processed movie 232
#
# Processing movie 233/250...
# Successfully fetched: https://www.imdb.com//title/tt0317705/?ref_=chttp_t_233
# English Title: The Incredibles
# Release Year: (2004)
# Rating: 8.0
# Director: Brad Bird
# Genres: Computer Animation,Superhero,Urban Adventure,Action,Adventure,Animation,Family
# Release Date: 2004
# Country: United States
# Official Sites: 52 found
# Languages: English,French,German,Italian,Portuguese,Russian
# Filming Location: Walt Disney Feature Animation - 500 S. Buena Vista Street, Burbank, California, USA
# Production Companies: Walt Disney Pictures,Pixar Animation Studios
# Gross Worldwide: $631,688,498
# Successfully processed movie 233
#
# Processing movie 234/250...
# Successfully fetched: https://www.imdb.com//title/tt1028532/?ref_=chttp_t_234
# English Title: Hachi: A Dog's Tale
# Release Year: (2009)
# Rating: 8.1
# Director: Lasse Hallström
# Genres: Animal Adventure,Biography,Drama,Family
# Release Date: 2009
# Country: United Kingdom
# Official Sites: 51 found
# Languages: English,Japanese
# Filming Location: Rhode Island, USA
# Production Companies: Stage 6 Films,Inferno Distribution,Hachiko
# Gross Worldwide: $46,749,646
# Successfully processed movie 234
#
# Processing movie 235/250...
# Successfully fetched: https://www.imdb.com//title/tt1979320/?ref_=chttp_t_235
# English Title: Rush
# Release Year: (2013)
# Rating: 8.1
# Director: Ron Howard
# Genres: Docudrama,Motorsport,Period Drama,Biography,Drama,Sport
# Release Date: 2013
# Country: United Kingdom
# Official Sites: 52 found
# Languages: English,German,Italian,French,Japanese,Spanish
# Filming Location: Nürburgring, Rhineland-Palatinate, Germany
# Production Companies: Exclusive Media Group,Cross Creek Pictures,Imagine Entertainment
# Gross Worldwide: $96,992,516
# Successfully processed movie 235
#
# Processing movie 236/250...
# Successfully fetched: https://www.imdb.com//title/tt0092005/?ref_=chttp_t_236
# English Title: Stand by Me
# Release Year: (1986)
# Rating: 8.1
# Director: Rob Reiner
# Genres: Coming-of-Age,Dark Comedy,Quest,Adventure,Comedy,Drama
# Release Date: 1986
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: Eagle Mountain Ln, Burney, California, USA
# Production Companies: Columbia Pictures,Act III,Act III Communications
# Gross Worldwide: $53,525,035
# Successfully processed movie 236
#
# Processing movie 237/250...
# Successfully fetched: https://www.imdb.com//title/tt0476735/?ref_=chttp_t_237
# English Title: My Father and My Son
# Release Year: (2005)
# Rating: 8.2
# Director: Çagan Irmak
# Genres: Coming-of-Age,Political Drama,Drama,Family
# Release Date: 2005
# Country: Turkey
# Official Sites: 53 found
# Languages: Turkish
# Filming Location: Seferihisar, Turkey
# Production Companies: Avsar Film
# Gross Worldwide: $18,612,999
# Successfully processed movie 237
#
# Processing movie 238/250...
# Successfully fetched: https://www.imdb.com//title/tt0074958/?ref_=chttp_t_238
# English Title: Network
# Release Year: (1976)
# Rating: 8.1
# Director: Sidney Lumet
# Genres: Dark Comedy,Workplace Drama,Drama
# Release Date: 1976
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: CTV Toronto Studios - 9 Channel Nine Court, Scarborough, Ontario, Canada
# Production Companies: Metro-Goldwyn-Mayer (MGM)
# Gross Worldwide: $23,701,317
# Successfully processed movie 238
#
# Processing movie 239/250...
# Successfully fetched: https://www.imdb.com//title/tt0129167/?ref_=chttp_t_239
# English Title: The Iron Giant
# Release Year: (1999)
# Rating: 8.1
# Director: Brad Bird
# Genres: Alien Invasion,Artificial Intelligence,Hand-Drawn Animation,High-Concept Comedy,Kaiju,Space Sci-Fi,Action,Adventure,Animation,Comedy
# Release Date: 1999
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: Los Angeles, California, USA
# Production Companies: Warner Bros.,Warner Bros. Animation,Warner Bros. Feature Animation
# Gross Worldwide: $23,338,352
# Successfully processed movie 239
#
# Processing movie 240/250...
# Successfully fetched: https://www.imdb.com//title/tt4016934/?ref_=chttp_t_240
# English Title: The Handmaiden
# Release Year: (2016)
# Rating: 8.1
# Director: Park Chan-wook
# Genres: Dark Romance,Erotic Thriller,Psychological Thriller,Steamy Romance,Drama,Romance,Thriller
# Release Date: 2016
# Country: South Korea
# Official Sites: 52 found
# Languages: Korean,Japanese
# Filming Location: Nagoya, Aichi, Japan
# Production Companies: CJ Entertainment,Moho Film,Yong Film
# Gross Worldwide: $37,863,670
# Successfully processed movie 240
#
# Processing movie 241/250...
# Successfully fetched: https://www.imdb.com//title/tt0035446/?ref_=chttp_t_241
# English Title: To Be or Not to Be
# Release Year: (1942)
# Rating: 8.1
# Director: Ernst Lubitsch
# Genres: Screwball Comedy,Comedy,Romance,War
# Release Date: 1942
# Country: United States
# Official Sites: 54 found
# Languages: English,German,French
# Location not found
# Production Companies: Romaine Film Corporation
# Gross Worldwide: $4,578,000
# Successfully processed movie 241
#
# Processing movie 242/250...
# Successfully fetched: https://www.imdb.com//title/tt0058946/?ref_=chttp_t_242
# English Title: The Battle of Algiers
# Release Year: (1966)
# Rating: 8.1
# Director: Gillo Pontecorvo
# Genres: Docudrama,Political Drama,Drama,War
# Release Date: 1966
# Country: Italy
# Official Sites: 52 found
# Languages: Arabic,French,English,Spanish
# Filming Location: Casbah, Algiers, Algeria
# Production Companies: Igor Film,Casbah Film
# Gross Worldwide: $962,002
# Successfully processed movie 242
#
# Processing movie 243/250...
# Successfully fetched: https://www.imdb.com//title/tt5323662/?ref_=chttp_t_243
# English Title: A Silent Voice: The Movie
# Release Year: (2016)
# Rating: 8.1
# Director: Naoko Yamada
# Genres: Anime,Coming-of-Age,Psychological Drama,Shōnen,Slice of Life,Animation,Drama
# Release Date: 2016
# Country: Japan
# Official Sites: 53 found
# Languages: Japanese,Japanese Sign Language,English
# Location not found
# Production Companies: ABC Animation,Kyoto Animation,Kôdansha
# Gross Worldwide: $30,819,442
# Successfully processed movie 243
#
# Processing movie 244/250...
# Successfully fetched: https://www.imdb.com//title/tt0032551/?ref_=chttp_t_244
# English Title: The Grapes of Wrath
# Release Year: (1940)
# Rating: 8.1
# Director: John Ford
# Genres: Period Drama,Tragedy,Drama
# Release Date: 1940
# Country: United States
# Official Sites: 51 found
# Languages: English
# Filming Location: Santa Rosa, New Mexico, USA
# Production Companies: Twentieth Century Fox
# Gross Worldwide: $7,304
# Successfully processed movie 244
#
# Processing movie 245/250...
# Successfully fetched: https://www.imdb.com//title/tt0758758/?ref_=chttp_t_245
# English Title: Into the Wild
# Release Year: (2007)
# Rating: 8.0
# Director: Sean Penn
# Genres: Coming-of-Age,Docudrama,Road Trip,Survival,Tragedy,Adventure,Biography,Drama
# Release Date: 2007
# Country: United States
# Official Sites: 50 found
# Languages: English,Danish
# Filming Location: Astoria, Oregon, USA
# Production Companies: Paramount Vantage,Art Linson Productions,Into the Wild
# Gross Worldwide: $56,676,733
# Successfully processed movie 245
#
# Processing movie 246/250...
# Successfully fetched: https://www.imdb.com//title/tt0107048/?ref_=chttp_t_246
# English Title: Groundhog Day
# Release Year: (1993)
# Rating: 8.0
# Director: Harold Ramis
# Genres: Feel-Good Romance,High-Concept Comedy,Holiday Comedy,Holiday Romance,Romantic Comedy,Comedy,Drama,Fantasy,Romance
# Release Date: 1993
# Country: United States
# Official Sites: 51 found
# Languages: English,French,Italian
# Filming Location: 344 Fremont St, Woodstock, Illinois, USA
# Production Companies: Columbia Pictures
# Gross Worldwide: $71,108,778
# Successfully processed movie 246
#
# Processing movie 247/250...
# Successfully fetched: https://www.imdb.com//title/tt1454029/?ref_=chttp_t_247
# English Title: The Help
# Release Year: (2011)
# Rating: 8.1
# Director: Tate Taylor
# Genres: Period Drama,Drama
# Release Date: 2011
# Country: United States
# Official Sites: 50 found
# Languages: English
# Filming Location: Greenwood, Mississippi, USA
# Production Companies: DreamWorks,Dreamworks Pictures,Reliance Film & Entertainment
# Gross Worldwide: $221,802,186
# Successfully processed movie 247
#
# Processing movie 248/250...
# Successfully fetched: https://www.imdb.com//title/tt0245712/?ref_=chttp_t_248
# English Title: Amores Perros
# Release Year: (2000)
# Rating: 8.0
# Director: Alejandro G. Iñárritu
# Genres: Tragedy,Drama,Thriller
# Release Date: 2000
# Country: Mexico
# Official Sites: 53 found
# Languages: Spanish
# Filming Location: Colonia Condesa, Mexico City, Distrito Federal, Mexico
# Production Companies: Altavista Films,Zeta Film
# Gross Worldwide: $20,908,467
# Successfully processed movie 248
#
# Processing movie 249/250...
# Successfully fetched: https://www.imdb.com//title/tt0032976/?ref_=chttp_t_249
# English Title: Rebecca
# Release Year: (1940)
# Rating: 8.1
# Director: Alfred Hitchcock
# Genres: Dark Romance,Psychological Drama,Psychological Thriller,Suspense Mystery,Drama,Mystery,Romance,Thriller
# Release Date: 1940
# Country: United States
# Official Sites: 51 found
# Languages: English,French
# Filming Location: Big Sur, California, USA
# Production Companies: Selznick International Pictures
# Gross Worldwide: $113,328
# Successfully processed movie 249
#
# Processing movie 250/250...
# Successfully fetched: https://www.imdb.com//title/tt16492678/?ref_=chttp_t_250
# English Title: Demon Slayer: Kimetsu no Yaiba - Tsuzumi Mansion Arc
# Release Year: (2021)
# Rating: 8.5
# Director: Haruo Sotozaki
# Genres: Anime,Supernatural Fantasy,Action,Animation,Fantasy
# Release Date: 2021
# Country: Japan
# Official Sites: 48 found
# Languages: Japanese
# Location not found
# Production Companies: Ufotable
# Gross Worldwide: $67,358
# Successfully processed movie 250
#
# All movies processed successfully!
#
# Results saved to 'imdb_top_movies.csv'

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 2.8rem; color: #f8f8f2; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); background-color: #282a36; padding: 20px; border-radius: 20px; border: 7px solid #bd93f9; width: 95%;">
#   <span style="font-weight: bold; color: #ff79c6; animation: pulse 2s infinite;">Extracting Full Cast & Crew </span>
#   <span style="font-style: italic; color: #8be9fd; animation: pulse 2s infinite;">Including Producers 🎥</span>
# </p>
#
# <style>
# @keyframes pulse {
#   0% {
#     transform: scale(1);
#   }
#   50% {
#     transform: scale(1.05);
#   }
#   100% {
#     transform: scale(1);
#   }
# }
# </style>

# %%
def extract_link_crew(links):
    crew_links = []
    driver = webdriver.Chrome()

    for i, movie_link in enumerate(links):

        print(f"Extract crew Movie Number {i+1}".title())
            
        driver.get(movie_link)
        soup = BeautifulSoup(driver.page_source)
        time.sleep(random.randint(1, 4))

        try:
            crew_link = soup.find('a', {'aria-label': re.compile(r'See full cast and crew')}).get('href')
            crew_links.append(f"https://www.imdb.com{crew_link}")
        except:
            crew_links.append(None)
    driver.close()
            
            
    pd.DataFrame({'LINKS_CREW':crew_links}).to_csv('LINKS_CREW.csv',index=False)
extract_link_crew(all_links[:5])
# Out:
# Extract Crew Movie Number 1
# Extract Crew Movie Number 2
# Extract Crew Movie Number 3
# Extract Crew Movie Number 4
# Extract Crew Movie Number 5

# %%
links_crew=pd.read_csv(r'D:\assignment data engineering\extract\LINKS_CREW.csv')
links_crew.loc[75]='https://www.imdb.com/title/tt4154796/fullcredits/?ref_=tt_ov_ql_1'
links_crew.loc[245]='https://www.imdb.com/title/tt16492678/fullcredits/?ref_=tt_ov_ql_1'
links_crew.to_csv('Links_crew.csv',index=False)

# %%
class IMDbScraper:
    def __init__(self, csv_path):
        self.csv_path = csv_path
        self.role_cache = {}
        self.driver = webdriver.Chrome()
        self.all_data = pd.DataFrame()

    def get_primary_role_fast(self, actor_url):
        try:
            if actor_url in self.role_cache:
                return self.role_cache[actor_url]
            
            base_url = "https://www.imdb.com"
            full_url = base_url + actor_url
            headers = {"User-Agent": "Mozilla/5.0"}
            response = requests.get(full_url, headers=headers, timeout=10)
            soup = BeautifulSoup(response.content, 'html.parser')

            ul = soup.find('ul', class_='ipc-inline-list ipc-inline-list--show-dividers sc-ec65ba05-2 joVhBE baseAlt')
            if ul:
                li = ul.find('li')
                if li:
                    role = li.text.strip()
                    self.role_cache[actor_url] = role
                    return role
        except Exception as e:
            print(f"Error (requests) fetching role for {actor_url}: {e}")
        return None

    def extract_data_link(self, link, rank):
        data = {
            'Movie_ID': [], 
            'Names': [], 
            'Characters_Position': [], 
            'Rank': [], 
            'Primary_Role': []
        }

        try:
            self.driver.get(link)
            time.sleep(random.uniform(1.5, 2.5))
            soup = BeautifulSoup(self.driver.page_source, 'html.parser')

            cast_info = soup.find_all('div', class_='sc-eaa440fc-3 iDfWju')

            for i in cast_info:
                name_tag = i.find('a', class_='ipc-link ipc-link--base name-credits--title-text name-credits--title-text-big')
                character_position = i.find('a', class_='ipc-link ipc-link--base ipc-link--inherit-color')
                actor_link_tag = i.find('a', class_='ipc-link ipc-link--base name-credits--title-text name-credits--title-text-small')

                if name_tag and character_position and actor_link_tag:
                    first_part_name = name_tag.text.strip()
                    character_position_text = character_position.text.strip()
                    actor_relative_link = actor_link_tag['href']
                    primary_role = self.get_primary_role_fast(actor_relative_link)

                    movies_ID = re.search(r'tt(\d{7})', link).group(1)

                    data['Movie_ID'].append(movies_ID)
                    data['Names'].append(first_part_name)
                    data['Characters_Position'].append(character_position_text)
                    data['Rank'].append(rank)
                    data['Primary_Role'].append(primary_role)
        except Exception as e:
            print(f"Error while processing {link}: {e}")

        return pd.DataFrame(data)

    def run(self, limit=None):
        links = pd.read_csv(self.csv_path)

        links_to_process = links['LINKS_CREW'] if limit is None else links['LINKS_CREW'][:limit]

        for i, link in enumerate(links_to_process, start=1):
            print(f"Processing link {i}/{len(links_to_process)}: {link}")
            df = self.extract_data_link(link, i)
            self.all_data = pd.concat([self.all_data, df], ignore_index=True)

        self.driver.quit()
        self.all_data.to_csv('all_cast_and_crew_with_roles.csv', index=False)
        print("All data saved to 'all_cast_and_crew_with_roles.csv'")


if __name__ == "__main__":
    scraper = IMDbScraper(r'D:\assignment data engineering\extract\LINKS_CREW.csv')
    scraper.run()
# Out:
# Processing 1/2: https://www.imdb.com/title/tt0111161/fullcredits/?ref_=tt_ov_st#cast
# Processing 2/2: https://www.imdb.com/title/tt0068646/fullcredits/?ref_=tt_ov_wr#writer
# Empty DataFrame
# Columns: []
# Index: []
# Data saved to full_cast_and_crew.csv

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3.5rem; color: #ffffff; text-align: center; margin: 0; text-shadow: 3px 3px 6px rgba(0, 0, 0, 0.6); background: linear-gradient(135deg, #1f4037, #99f2c8); padding: 30px; border-radius: 25px; border: 7px solid #0f9d58; width: 95%; letter-spacing: 1.5px;">
#   💾 <span style="color: #ffeb3b;">Database Integration:</span> <span style="color: #ffffff;">Storing Cleaned Data</span> 📊
# </p>

# %%
class Bronze_layer:
    def __init__(self, data, name_data_base):
        if not isinstance(data, pd.DataFrame):
            raise ValueError("The data parameter should be a valid pandas DataFrame.")
        
        self.data = data
        self.name_data_base = name_data_base
        
    def create_data_base(self, user_name, input_host, input_password):
        try:
            with connector.connect(
                host=input_host,
                user=user_name,
                password=input_password
            ) as db:
            
                cursor = db.cursor()
                cursor.execute(f"CREATE DATABASE IF NOT EXISTS {self.name_data_base}")
                
                print(f"Database '{self.name_data_base}' created or already exists.")
            
        except connector.Error as err:
            print(f"Error while creating database: {err}")

            
    def data_storage(self, name_table):
        try:
            engine = create_engine(f'mysql+pymysql://root:2003@localhost:3306/{self.name_data_base}')
            self.data.to_sql(name=name_table, con=engine, index=False, if_exists='replace')
            print(f"Data stored successfully in table '{name_table}'.")
        except Exception as e:
            print(f"Error while storing data: {e}")
            
def test_data_data_base(name_data_base, name_table):
    try:
        with  connector.connect(
            host='localhost',
            user='root',
            password='2003',
            database=name_data_base
        ) as db:
            cursor = db.cursor()
            cursor.execute(f'''SELECT * FROM {name_table}
                           where rating > 5.5
                           order by rank asc''')
            rs = cursor.fetchall()
            if rs:
                data = pd.DataFrame(rs, columns=[col[0] for col in cursor.description])
                return data
            else:
                print(f"No data found for the query.")

        return data
    except connector.Error as err:
        print(f"Error while fetching data: {err}")


if __name__ == '__main__':
    info_data = pd.read_csv(r'D:\assignment data engineering\extract\imdb_top_movies.csv')
    name_data_base = 'Bronze_layer'
    storage_info_data = Bronze_layer(info_data, name_data_base)
    
    storage_info_data.create_data_base('root', 'localhost', '2003')
    
    name_table_1 = 'imdb_top_movies'
    storage_info_data.data_storage(name_table_1)
    
    data = test_data_data_base(name_data_base, name_table_1)
    if data is not None:
        print(data.head(5))
    print("*"*100)  
    #storage data all cast and crew
    all_cast_crew = pd.read_csv(r'D:\assignment data engineering\extract\all_cast_and_crew_with_roles.csv')
    storage_all_cast_crew = Bronze_layer(all_cast_crew, name_data_base)
    
    name_table_2 = 'all_cast_and_crew_with_roles'
    storage_all_cast_crew.data_storage(name_table_2)
    crew_all_cast = test_data_data_base(name_data_base, name_table_2)
    if crew_all_cast is not None:
        print(crew_all_cast.head(5))
# Out:
# Database 'Bronze_layer' created or already exists.
# Data stored successfully in table 'imdb_top_movies'.
#    Movie_ID  Rank                     Title Release Year  Rating  \
# 0    111161     1  The Shawshank Redemption       (1994)     9.3
# 1     68646     2             The Godfather       (1972)     9.2
# 2    468569     3           The Dark Knight       (2008)     9.0
# 3     71562     4     The Godfather Part II       (1974)     9.0
# 4     50083     5              12 Angry Men       (1957)     9.0
#
#               Directors                                             Genres  \
# 0        Frank Darabont               Epic,Period Drama,Prison Drama,Drama
# 1  Francis Ford Coppola                  Epic,Gangster,Tragedy,Crime,Drama
# 2     Christopher Nolan  Action Epic,Epic,Superhero,Tragedy,Action,Crim...
# 3  Francis Ford Coppola                  Epic,Gangster,Tragedy,Crime,Drama
# 4          Sidney Lumet        Legal Drama,Psychological Drama,Crime,Drama
#
#    Release Date Country of Origin  \
# 0          1994     United States
# 1          1972     United States
# 2          2008     United States
# 3          1974     United States
# 4          1957     United States
#
#                                       Official Sites  \
# 0  ['https://help.imdb.com/imdb?ref_=cons_nb_hlp'...
# 1  ['https://help.imdb.com/imdb?ref_=cons_nb_hlp'...
# 2  ['https://help.imdb.com/imdb?ref_=cons_nb_hlp'...
# 3  ['https://help.imdb.com/imdb?ref_=cons_nb_hlp'...
# 4  ['https://help.imdb.com/imdb?ref_=cons_nb_hlp'...
#
#                                 Languages  \
# 0                                 English
# 1                   English,Italian,Latin
# 2                        English,Mandarin
# 3  English,Italian,Spanish,Latin,Sicilian
# 4                                 English
#
#                                            Locations  \
# 0  Mansfield Reformatory - 100 Reformatory Road, ...
# 1               Forza d'Agrò, Messina, Sicily, Italy
# 2                             Chicago, Illinois, USA
# 3  Kaiser Estate - 4000 W Lake Blvd, Homewood, La...
# 4  New York County Courthouse - 60 Centre Street,...
#
#                                 Production Companies Gross Worldwide
# 0                          Castle Rock Entertainment     $29,332,133
# 1  Paramount Pictures,Albert S. Ruddy Productions...    $250,342,198
# 2       Warner Bros.,Legendary Entertainment,Syncopy  $1,009,057,329
# 3  Paramount Pictures,The Coppola Company,America...     $47,980,865
# 4                             Orion-Nova Productions          $2,945
# ****************************************************************************************************
# Data stored successfully in table 'all_cast_and_crew_with_roles'.
#    Movie_ID           Names       Characters_Position  Rank Primary_Role
# 0    111161     Tim Robbins             Andy Dufresne   1.0        Actor
# 1    111161  Morgan Freeman  Ellis Boyd 'Red' Redding   1.0        Actor
# 2    111161      Bob Gunton             Warden Norton   1.0        Actor
# 3    111161  William Sadler                   Heywood   1.0        Actor
# 4    111161    Clancy Brown            Captain Hadley   1.0        Actor
